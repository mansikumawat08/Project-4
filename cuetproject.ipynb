# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r'C:\Users\Pc\Downloads\cust_satisfaction.csv')

# %%
df
# Out:
#         Gender      Customer Type   Type of Travel     Class  \
# 0         Male     Loyal Customer  Personal Travel  Eco Plus
# 1         Male  disloyal Customer  Business travel  Business
# 2       Female     Loyal Customer  Business travel  Business
# 3       Female     Loyal Customer  Business travel  Business
# 4         Male     Loyal Customer  Business travel  Business
# ...        ...                ...              ...       ...
# 103899  Female  disloyal Customer  Business travel       Eco
# 103900    Male     Loyal Customer  Business travel  Business
# 103901    Male  disloyal Customer  Business travel  Business
# 103902  Female  disloyal Customer  Business travel       Eco
# 103903    Male     Loyal Customer  Business travel  Business
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0       neutral or dissatisfied   13              460                       5
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Gender                      103904 non-null  str
#  1   Customer Type               103904 non-null  str
#  2   Type of Travel              103904 non-null  str
#  3   Class                       103904 non-null  str
#  4   satisfaction                103904 non-null  str
#  5   Age                         103904 non-null  int64
#  6   Flight Distance             103904 non-null  int64
#  7   Inflight entertainment      103904 non-null  int64
#  8   Baggage handling            103904 non-null  int64
#  9   Cleanliness                 103904 non-null  int64
#  10  Departure Delay in Minutes  103904 non-null  int64
#  11  Arrival Delay in Minutes    103594 non-null  float64
# dtypes: float64(1), int64(6), str(5)
# memory usage: 9.5 MB

# %%
df.columns
# Out:
# Index(['Gender', 'Customer Type', 'Type of Travel', 'Class', 'satisfaction',
#        'Age', 'Flight Distance', 'Inflight entertainment', 'Baggage handling',
#        'Cleanliness', 'Departure Delay in Minutes',
#        'Arrival Delay in Minutes'],
#       dtype='str')

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 103899    False
# 103900    False
# 103901    False
# 103902    False
# 103903    False
# Length: 103904, dtype: bool

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# Gender                        0
# Customer Type                 0
# Type of Travel                0
# Class                         0
# satisfaction                  0
# Age                           0
# Flight Distance               0
# Inflight entertainment        0
# Baggage handling              0
# Cleanliness                   0
# Departure Delay in Minutes    0
# Arrival Delay in Minutes      0
# dtype: int64

# %%
satisfaction_count = df['satisfaction'].value_counts()
label = ["neutral or dissatisfied", "satisfied"]
plt.pie(satisfaction_count,labels = label , autopct = "%1.1f%%")
plt.show()

# %%
sns.countplot(x='satisfaction', data=df)

plt.title('Distribution of Customer Satisfaction')
plt.xlabel('Satisfaction')
plt.ylabel('Number of Passengers')
# Out:
# Text(0, 0.5, 'Number of Passengers')

# %%
sns.countplot(x='Gender',hue='satisfaction',data=df)
plt.title('Gender vs Satisfaction')
plt.xlabel('Gender')
plt.ylabel('Number of Passengers')
plt.legend(title='Satisfaction')
plt.show()

# %%
sns.countplot(x='Customer Type', hue='satisfaction', data=df)
plt.title('Customer Type vs Satisfaction')
plt.xlabel('Customer Type')
plt.ylabel('Number of Passengers')
# Out:
# Text(0, 0.5, 'Number of Passengers')

# %%
sns.countplot(x='Type of Travel', hue='satisfaction', data=df)
plt.title('Type of Travel vs Satisfaction')
plt.xlabel('Type of Travel')
plt.ylabel('Number of Passengers')
# Out:
# Text(0, 0.5, 'Number of Passengers')

# %%
sns.countplot(x='Class', hue='satisfaction', data=df)

plt.title('Passenger Class vs Satisfaction')
plt.xlabel('Travel Class')
plt.ylabel('Number of Passengers')
# Out:
# Text(0, 0.5, 'Number of Passengers')

# %%
sns.boxplot(x='satisfaction', y='Age', data=df)

plt.title('Age by Satisfaction')
plt.xlabel('Satisfaction')
plt.ylabel('Age')
# Out:
# Text(0, 0.5, 'Age')

# %%
avg_dist = df.groupby('satisfaction')['Flight Distance'].mean()
avg_dist.plot(kind='bar')
plt.title('Average Flight Distance by Satisfaction')
plt.xlabel('Satisfaction')
plt.ylabel('Average Flight Distance')
# Out:
# Text(0, 0.5, 'Average Flight Distance')

# %%
sns.boxplot(x='satisfaction',y='Inflight entertainment',data=df)
plt.title('Inflight Entertainment Rating by Satisfaction')
plt.xlabel('Satisfaction')
plt.ylabel('Entertainment Rating')
# Out:
# Text(0, 0.5, 'Entertainment Rating')

# %%
sns.boxplot(x='satisfaction',y='Baggage handling',data=df)
plt.title('Baggage Handling Rating by Satisfaction')
plt.xlabel('Satisfaction')
plt.ylabel('Baggage Handling Rating')
# Out:
# Text(0, 0.5, 'Baggage Handling Rating')

# %%
sns.boxplot(x='satisfaction',y='Cleanliness',data=df)

plt.title('Cleanliness Rating by Satisfaction')
plt.xlabel('Satisfaction')
plt.ylabel('Cleanliness Rating')
# Out:
# Text(0, 0.5, 'Cleanliness Rating')

# %%
sns.barplot(x='satisfaction',y='Departure Delay in Minutes',data=df)

plt.title('Departure Delay by Satisfaction')
plt.xlabel('Satisfaction')
plt.ylabel('Departure Delay (Minutes)')
# Out:
# Text(0, 0.5, 'Departure Delay (Minutes)')

# %%
sns.barplot(x='satisfaction',y='Arrival Delay in Minutes',data=df)

plt.title('Arrival Delay Vs Satisfaction')
plt.xlabel('Satisfaction')
plt.ylabel('Arrival Delay (Minutes)')
# Out:
# Text(0, 0.5, 'Arrival Delay (Minutes)')

# %%
num_cols = [
    'Age',
    'Flight Distance',
    'Inflight entertainment',
    'Baggage handling',
    'Cleanliness',
    'Departure Delay in Minutes',
    'Arrival Delay in Minutes'
]

sns.heatmap(df[num_cols].corr(),
            annot=True,
            cmap='coolwarm')

plt.title('Correlation Heatmap')
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 103422 entries, 0 to 103903
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Gender                      103422 non-null  str
#  1   Customer Type               103422 non-null  str
#  2   Type of Travel              103422 non-null  str
#  3   Class                       103422 non-null  str
#  4   satisfaction                103422 non-null  str
#  5   Age                         103422 non-null  int64
#  6   Flight Distance             103422 non-null  int64
#  7   Inflight entertainment      103422 non-null  int64
#  8   Baggage handling            103422 non-null  int64
#  9   Cleanliness                 103422 non-null  int64
#  10  Departure Delay in Minutes  103422 non-null  int64
#  11  Arrival Delay in Minutes    103422 non-null  float64
# dtypes: float64(1), int64(6), str(5)
# memory usage: 10.3 MB

# %%
df['Gender'].unique()
# Out:
# <StringArray>
# ['Male', 'Female']
# Length: 2, dtype: str

# %%
Gender_dict = {'Male':1, 'Female':2}

# %%
df['Gender'] = df['Gender'].map(Gender_dict)

# %%
df
# Out:
#         Gender      Customer Type   Type of Travel     Class  \
# 0            1     Loyal Customer  Personal Travel  Eco Plus
# 1            1  disloyal Customer  Business travel  Business
# 2            2     Loyal Customer  Business travel  Business
# 3            2     Loyal Customer  Business travel  Business
# 4            1     Loyal Customer  Business travel  Business
# ...        ...                ...              ...       ...
# 103899       2  disloyal Customer  Business travel       Eco
# 103900       1     Loyal Customer  Business travel  Business
# 103901       1  disloyal Customer  Business travel  Business
# 103902       2  disloyal Customer  Business travel       Eco
# 103903       1     Loyal Customer  Business travel  Business
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0       neutral or dissatisfied   13              460                       5
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 103422 entries, 0 to 103903
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Gender                      103422 non-null  int64
#  1   Customer Type               103422 non-null  str
#  2   Type of Travel              103422 non-null  str
#  3   Class                       103422 non-null  str
#  4   satisfaction                103422 non-null  str
#  5   Age                         103422 non-null  int64
#  6   Flight Distance             103422 non-null  int64
#  7   Inflight entertainment      103422 non-null  int64
#  8   Baggage handling            103422 non-null  int64
#  9   Cleanliness                 103422 non-null  int64
#  10  Departure Delay in Minutes  103422 non-null  int64
#  11  Arrival Delay in Minutes    103422 non-null  float64
# dtypes: float64(1), int64(7), str(4)
# memory usage: 10.3 MB

# %%
df['Customer Type'].unique()
# Out:
# <StringArray>
# ['Loyal Customer', 'disloyal Customer']
# Length: 2, dtype: str

# %%
Customer_Type_dict = {'Loyal Customer':1,'disloyal Customer':2}

# %%
df['Customer Type'] = df['Customer Type'].map(Customer_Type_dict)

# %%
df['Type of Travel'].unique()
# Out:
# <StringArray>
# ['Personal Travel', 'Business travel']
# Length: 2, dtype: str

# %%
Type_of_Travel_dict = {'Personal Travel':1, 'Business travel':2}

# %%
df['Type of Travel'] = df['Type of Travel'].map(Type_of_Travel_dict)

# %%
df['Class'].unique()
# Out:
# <StringArray>
# ['Eco Plus', 'Business', 'Eco']
# Length: 3, dtype: str

# %%
Class_dict = {'Eco Plus':1, 'Business':2, 'Eco':3}

# %%
df['Class'] = df['Class'].map(Class_dict)

# %%
df['satisfaction'].unique()
# Out:
# <StringArray>
# ['neutral or dissatisfied', 'satisfied']
# Length: 2, dtype: str

# %%
satisfaction_dict = {'neutral or dissatisfied':1, 'satisfied':2}

# %%
df['satisfaction'] = df['satisfaction'].map(satisfaction_dict)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 103422 entries, 0 to 103903
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Gender                      103422 non-null  int64
#  1   Customer Type               103422 non-null  int64
#  2   Type of Travel              103422 non-null  int64
#  3   Class                       103422 non-null  int64
#  4   satisfaction                103422 non-null  int64
#  5   Age                         103422 non-null  int64
#  6   Flight Distance             103422 non-null  int64
#  7   Inflight entertainment      103422 non-null  int64
#  8   Baggage handling            103422 non-null  int64
#  9   Cleanliness                 103422 non-null  int64
#  10  Departure Delay in Minutes  103422 non-null  int64
#  11  Arrival Delay in Minutes    103422 non-null  float64
# dtypes: float64(1), int64(11)
# memory usage: 10.3 MB

# %%
df
# Out:
#         Gender  Customer Type  Type of Travel  Class  satisfaction  Age  \
# 0            1              1               1      1             1   13
# 1            1              2               2      2             1   25
# 2            2              1               2      2             2   26
# 3            2              1               2      2             1   25
# 4            1              1               2      2             2   61
# ...        ...            ...             ...    ...           ...  ...
# 103899       2              2               2      3             1   23
# 103900       1              1               2      2             2   49
# 103901       1              2               2      2             1   30
# 103902       2              2               2      3             1   22
# 103903       1              1               2      2             1   27
#
#         Flight Distance  Inflight entertainment  Baggage handling  \
# ...

# %%
df['Customer Type'].unique
# Out:
# <bound method Series.unique of 0         1
# 1         2
# 2         1
# 3         1
# 4         1
#          ..
# 103899    2
# 103900    1
# 103901    2
# 103902    2
# 103903    1
# Name: Customer Type, Length: 103422, dtype: int64>

# %%
df.drop(['Gender','Age'], axis=1 ,inplace = True)

# %%
df
# Out:
#         Customer Type  Type of Travel  Class  satisfaction  Flight Distance  \
# 0                   1               1      1             1              460
# 1                   2               2      2             1              235
# 2                   1               2      2             2             1142
# 3                   1               2      2             1              562
# 4                   1               2      2             2              214
# ...               ...             ...    ...           ...              ...
# 103899              2               2      3             1              192
# 103900              1               2      2             2             2347
# 103901              2               2      2             1             1995
# 103902              2               2      3             1             1000
# 103903              1               2      2             1             1723
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 103422 entries, 0 to 103903
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Customer Type               103422 non-null  int64
#  1   Type of Travel              103422 non-null  int64
#  2   Class                       103422 non-null  int64
#  3   satisfaction                103422 non-null  int64
#  4   Flight Distance             103422 non-null  int64
#  5   Inflight entertainment      103422 non-null  int64
#  6   Baggage handling            103422 non-null  int64
#  7   Cleanliness                 103422 non-null  int64
#  8   Departure Delay in Minutes  103422 non-null  int64
#  9   Arrival Delay in Minutes    103422 non-null  float64
# dtypes: float64(1), int64(9)
# memory usage: 8.7 MB

# %%
df.drop(['Departure Delay in Minutes', "Cleanliness"], axis =1 , inplace= True)

# %%
df
# Out:
#         Customer Type  Type of Travel  Class  satisfaction  Flight Distance  \
# 0                   1               1      1             1              460
# 1                   2               2      2             1              235
# 2                   1               2      2             2             1142
# 3                   1               2      2             1              562
# 4                   1               2      2             2              214
# ...               ...             ...    ...           ...              ...
# 103899              2               2      3             1              192
# 103900              1               2      2             2             2347
# 103901              2               2      2             1             1995
# 103902              2               2      3             1             1000
# 103903              1               2      2             1             1723
#
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(17398)

# %%
df.drop_duplicates(inplace = True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum()
# Out:
# Customer Type               0
# Type of Travel              0
# Class                       0
# satisfaction                0
# Flight Distance             0
# Inflight entertainment      0
# Baggage handling            0
# Arrival Delay in Minutes    0
# dtype: int64

# %%
df.to_csv("clean_customer_data.csv")

# %%
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC , SVR

# %%
x = df.drop(['satisfaction'],axis = 1)

# %%
y = df[["satisfaction"]]

# %%
x
# Out:
#         Customer Type  Type of Travel  Class  Flight Distance  \
# 0                   1               1      1              460
# 1                   2               2      2              235
# 2                   1               2      2             1142
# 3                   1               2      2              562
# 4                   1               2      2              214
# ...               ...             ...    ...              ...
# 103897              1               2      2             1599
# 103899              2               2      3              192
# 103901              2               2      2             1995
# 103902              2               2      3             1000
# 103903              1               2      2             1723
#
#         Inflight entertainment  Baggage handling  Arrival Delay in Minutes
# 0                            5                 4                      18.0
# ...

# %%
y
# Out:
#         satisfaction
# 0                  1
# 1                  1
# 2                  2
# 3                  1
# 4                  2
# ...              ...
# 103897             2
# 103899             1
# 103901             1
# 103902             1
# 103903             1
#
# [86024 rows x 1 columns]

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,random_state=42 , test_size=0.2)

# %%
x_train.shape , x_test.shape , y_train.shape , y_test.shape
# Out:
# ((68819, 7), (17205, 7), (68819, 1), (17205, 1))

# %%
sv = SVC()
sv.fit(x_train , y_train)
# Out:
# c:\Users\Pc\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC()

# %%
print(sv.score(x_train , y_train))
print(sv.score(x_test , y_test))
# Out:
# 0.6651796742178758
# 0.6625980819529207

# %%
from sklearn.tree import DecisionTreeClassifier , DecisionTreeRegressor
dtc = DecisionTreeClassifier()

# %%
dtc.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'random_state': None,
#  'splitter': 'best'}

# %%
dtc.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
print(dtc.score(x_train ,y_train))
print(dtc.score(x_test , y_test))
# Out:
# 0.9725511849925166
# 0.7410055216506829

# %%
x_train
# Out:
#        Customer Type  Type of Travel  Class  Flight Distance  \
# 37139              1               1      3             1235
# 26414              1               1      3              973
# 59908              1               2      3              590
# 1861               1               2      2             2139
# 67775              1               2      2              356
# ...              ...             ...    ...              ...
# 6393               2               2      2              843
# 62863              1               1      3             1524
# 91414              1               2      2             2942
# 862                1               1      3             2602
# 16616              1               2      1              448
#
#        Inflight entertainment  Baggage handling  Arrival Delay in Minutes
# 37139                       1                 3                      67.0
# 26414                       5                 4                       0.0
# ...

# %%
y_train
# Out:
#        satisfaction
# 37139             1
# 26414             1
# 59908             2
# 1861              2
# 67775             2
# ...             ...
# 6393              2
# 62863             1
# 91414             2
# 862               1
# 16616             1
#
# [68819 rows x 1 columns]

# %%
x_test
# Out:
#        Customer Type  Type of Travel  Class  Flight Distance  \
# 75122              1               1      3             1035
# 72539              1               1      3              925
# 10430              2               2      3             1205
# 72858              2               2      3              196
# 4205               1               2      2             2434
# ...              ...             ...    ...              ...
# 98265              1               2      2             1783
# 52956              1               2      3             1121
# 6568               1               2      2              239
# 16301              1               2      3              125
# 7628               1               2      2              268
#
#        Inflight entertainment  Baggage handling  Arrival Delay in Minutes
# 75122                       2                 4                      62.0
# 72539                       5                 3                      66.0
# ...

# %%
y_test
# Out:
#        satisfaction
# 75122             1
# 72539             1
# 10430             1
# 72858             1
# 4205              2
# ...             ...
# 98265             2
# 52956             1
# 6568              2
# 16301             1
# 7628              2
#
# [17205 rows x 1 columns]

# %%
dtc.predict([[1	, 1 , 3 , 1035 , 2 , 4 , 62.0]])
# Out:
# c:\Users\Pc\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])

# %%
from sklearn.metrics import confusion_matrix

# %%
y_pred = dtc.predict(x_test)

# %%
confusion_matrix(y_test , y_pred)
# Out:
# array([[8023, 2130],
#        [2326, 4726]])

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test , y_pred)
# Out:
# 0.7410055216506829
