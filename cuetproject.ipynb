# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r'C:\Users\Pc\Downloads\cust_satisfaction.csv')

# %%
df
# Out:
#         Gender      Customer Type   Type of Travel     Class  \
# 0         Male     Loyal Customer  Personal Travel  Eco Plus
# 1         Male  disloyal Customer  Business travel  Business
# 2       Female     Loyal Customer  Business travel  Business
# 3       Female     Loyal Customer  Business travel  Business
# 4         Male     Loyal Customer  Business travel  Business
# ...        ...                ...              ...       ...
# 103899  Female  disloyal Customer  Business travel       Eco
# 103900    Male     Loyal Customer  Business travel  Business
# 103901    Male  disloyal Customer  Business travel  Business
# 103902  Female  disloyal Customer  Business travel       Eco
# 103903    Male     Loyal Customer  Business travel  Business
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0       neutral or dissatisfied   13              460                       5
# ...

# %%
df.tail(15)
# Out:
#         Gender      Customer Type   Type of Travel     Class  \
# 103889  Female     Loyal Customer  Business travel  Business
# 103890  Female     Loyal Customer  Business travel  Eco Plus
# 103891    Male     Loyal Customer  Business travel  Business
# 103892  Female  disloyal Customer  Business travel  Business
# 103893  Female     Loyal Customer  Business travel  Business
# 103894    Male     Loyal Customer  Business travel  Business
# 103895  Female  disloyal Customer  Business travel       Eco
# 103896    Male     Loyal Customer  Business travel       Eco
# 103897  Female     Loyal Customer  Business travel  Business
# 103898    Male     Loyal Customer  Personal Travel       Eco
# 103899  Female  disloyal Customer  Business travel       Eco
# 103900    Male     Loyal Customer  Business travel  Business
# 103901    Male  disloyal Customer  Business travel  Business
# 103902  Female  disloyal Customer  Business travel       Eco
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Gender                      103904 non-null  str
#  1   Customer Type               103904 non-null  str
#  2   Type of Travel              103904 non-null  str
#  3   Class                       103904 non-null  str
#  4   satisfaction                103904 non-null  str
#  5   Age                         103904 non-null  int64
#  6   Flight Distance             103904 non-null  int64
#  7   Inflight entertainment      103904 non-null  int64
#  8   Baggage handling            103904 non-null  int64
#  9   Cleanliness                 103904 non-null  int64
#  10  Departure Delay in Minutes  103904 non-null  int64
#  11  Arrival Delay in Minutes    103594 non-null  float64
# dtypes: float64(1), int64(6), str(5)
# memory usage: 9.5 MB

# %%
df.columns
# Out:
# Index(['Gender', 'Customer Type', 'Type of Travel', 'Class', 'satisfaction',
#        'Age', 'Flight Distance', 'Inflight entertainment', 'Baggage handling',
#        'Cleanliness', 'Departure Delay in Minutes',
#        'Arrival Delay in Minutes'],
#       dtype='str')

# %%
df[["Age"]]
# Out:
#         Age
# 0        13
# 1        25
# 2        26
# 3        25
# 4        61
# ...     ...
# 103899   23
# 103900   49
# 103901   30
# 103902   22
# 103903   27
#
# [103904 rows x 1 columns]

# %%
df[["Age","Class"]]
# Out:
#         Age     Class
# 0        13  Eco Plus
# 1        25  Business
# 2        26  Business
# 3        25  Business
# 4        61  Business
# ...     ...       ...
# 103899   23       Eco
# 103900   49  Business
# 103901   30  Business
# 103902   22       Eco
# 103903   27  Business
#
# [103904 rows x 2 columns]

# %%
df["Customer Type"].unique()
# Out:
# <StringArray>
# ['Loyal Customer', 'disloyal Customer']
# Length: 2, dtype: str

# %%
df['Customer Type'].nunique()
# Out:
# 2

# %%
df['Customer Type'].value_counts()
# Out:
# Customer Type
# Loyal Customer       84923
# disloyal Customer    18981
# Name: count, dtype: int64

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 103899    False
# 103900    False
# 103901    False
# 103902    False
# 103903    False
# Length: 103904, dtype: bool

# %%
df['Class'].unique()
# Out:
# <StringArray>
# ['Eco Plus', 'Business', 'Eco']
# Length: 3, dtype: str

# %%
df.drop_duplicates()
# Out:
#         Gender      Customer Type   Type of Travel     Class  \
# 0         Male     Loyal Customer  Personal Travel  Eco Plus
# 1         Male  disloyal Customer  Business travel  Business
# 2       Female     Loyal Customer  Business travel  Business
# 3       Female     Loyal Customer  Business travel  Business
# 4         Male     Loyal Customer  Business travel  Business
# ...        ...                ...              ...       ...
# 103899  Female  disloyal Customer  Business travel       Eco
# 103900    Male     Loyal Customer  Business travel  Business
# 103901    Male  disloyal Customer  Business travel  Business
# 103902  Female  disloyal Customer  Business travel       Eco
# 103903    Male     Loyal Customer  Business travel  Business
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0       neutral or dissatisfied   13              460                       5
# ...

# %%
df
# Out:
#         Gender      Customer Type   Type of Travel     Class  \
# 0         Male     Loyal Customer  Personal Travel  Eco Plus
# 1         Male  disloyal Customer  Business travel  Business
# 2       Female     Loyal Customer  Business travel  Business
# 3       Female     Loyal Customer  Business travel  Business
# 4         Male     Loyal Customer  Business travel  Business
# ...        ...                ...              ...       ...
# 103899  Female  disloyal Customer  Business travel       Eco
# 103900    Male     Loyal Customer  Business travel  Business
# 103901    Male  disloyal Customer  Business travel  Business
# 103902  Female  disloyal Customer  Business travel       Eco
# 103903    Male     Loyal Customer  Business travel  Business
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0       neutral or dissatisfied   13              460                       5
# ...

# %%
df["Type of Travel"].unique()
# Out:
# <StringArray>
# ['Personal Travel', 'Business travel']
# Length: 2, dtype: str

# %%
df['Age'].describe()
# Out:
# count    103904.000000
# mean         39.379706
# std          15.114964
# min           7.000000
# 25%          27.000000
# 50%          40.000000
# 75%          51.000000
# max          85.000000
# Name: Age, dtype: float64

# %%
df[df['Age'] < 50]
# Out:
#         Gender      Customer Type   Type of Travel     Class  \
# 0         Male     Loyal Customer  Personal Travel  Eco Plus
# 1         Male  disloyal Customer  Business travel  Business
# 2       Female     Loyal Customer  Business travel  Business
# 3       Female     Loyal Customer  Business travel  Business
# 5       Female     Loyal Customer  Personal Travel       Eco
# ...        ...                ...              ...       ...
# 103899  Female  disloyal Customer  Business travel       Eco
# 103900    Male     Loyal Customer  Business travel  Business
# 103901    Male  disloyal Customer  Business travel  Business
# 103902  Female  disloyal Customer  Business travel       Eco
# 103903    Male     Loyal Customer  Business travel  Business
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0       neutral or dissatisfied   13              460                       5
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Gender                      103904 non-null  str
#  1   Customer Type               103904 non-null  str
#  2   Type of Travel              103904 non-null  str
#  3   Class                       103904 non-null  str
#  4   satisfaction                103904 non-null  str
#  5   Age                         103904 non-null  int64
#  6   Flight Distance             103904 non-null  int64
#  7   Inflight entertainment      103904 non-null  int64
#  8   Baggage handling            103904 non-null  int64
#  9   Cleanliness                 103904 non-null  int64
#  10  Departure Delay in Minutes  103904 non-null  int64
#  11  Arrival Delay in Minutes    103594 non-null  float64
# dtypes: float64(1), int64(6), str(5)
# memory usage: 9.5 MB

# %%
df[df["Flight Distance"] > 1000]
# Out:
#         Gender      Customer Type   Type of Travel     Class  \
# 2       Female     Loyal Customer  Business travel  Business
# 5       Female     Loyal Customer  Personal Travel       Eco
# 6         Male     Loyal Customer  Personal Travel       Eco
# 7       Female     Loyal Customer  Business travel  Business
# 9         Male  disloyal Customer  Business travel       Eco
# ...        ...                ...              ...       ...
# 103897  Female     Loyal Customer  Business travel  Business
# 103898    Male     Loyal Customer  Personal Travel       Eco
# 103900    Male     Loyal Customer  Business travel  Business
# 103901    Male  disloyal Customer  Business travel  Business
# 103903    Male     Loyal Customer  Business travel  Business
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 2                     satisfied   26             1142                       5
# ...

# %%
df[df['Cleanliness'] == 5]
# Out:
#         Gender      Customer Type   Type of Travel     Class  \
# 0         Male     Loyal Customer  Personal Travel  Eco Plus
# 2       Female     Loyal Customer  Business travel  Business
# 17        Male     Loyal Customer  Business travel  Business
# 19        Male     Loyal Customer  Personal Travel       Eco
# 21      Female     Loyal Customer  Personal Travel       Eco
# ...        ...                ...              ...       ...
# 103876  Female     Loyal Customer  Business travel  Business
# 103877    Male     Loyal Customer  Business travel  Eco Plus
# 103884  Female     Loyal Customer  Personal Travel       Eco
# 103886    Male  disloyal Customer  Business travel  Business
# 103894    Male     Loyal Customer  Business travel  Business
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0       neutral or dissatisfied   13              460                       5
# ...

# %%
df.drop(['Class'],axis=1)
# Out:
#         Gender      Customer Type   Type of Travel             satisfaction  \
# 0         Male     Loyal Customer  Personal Travel  neutral or dissatisfied
# 1         Male  disloyal Customer  Business travel  neutral or dissatisfied
# 2       Female     Loyal Customer  Business travel                satisfied
# 3       Female     Loyal Customer  Business travel  neutral or dissatisfied
# 4         Male     Loyal Customer  Business travel                satisfied
# ...        ...                ...              ...                      ...
# 103899  Female  disloyal Customer  Business travel  neutral or dissatisfied
# 103900    Male     Loyal Customer  Business travel                satisfied
# 103901    Male  disloyal Customer  Business travel  neutral or dissatisfied
# 103902  Female  disloyal Customer  Business travel  neutral or dissatisfied
# 103903    Male     Loyal Customer  Business travel  neutral or dissatisfied
#
# ...

# %%
df[df['Inflight entertainment'] < 5]
# Out:
#         Gender      Customer Type   Type of Travel     Class  \
# 1         Male  disloyal Customer  Business travel  Business
# 3       Female     Loyal Customer  Business travel  Business
# 4         Male     Loyal Customer  Business travel  Business
# 5       Female     Loyal Customer  Personal Travel       Eco
# 6         Male     Loyal Customer  Personal Travel       Eco
# ...        ...                ...              ...       ...
# 103898    Male     Loyal Customer  Personal Travel       Eco
# 103899  Female  disloyal Customer  Business travel       Eco
# 103901    Male  disloyal Customer  Business travel  Business
# 103902  Female  disloyal Customer  Business travel       Eco
# 103903    Male     Loyal Customer  Business travel  Business
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 1       neutral or dissatisfied   25              235                       1
# ...

# %%
plt.plot(df["Class"], df["Age"])
plt.show()

# %%
sns.histplot(df['Age'])
plt.show()

# %%
plt.hist(df['Flight Distance'])
plt.show()
